# %% [markdown]
# 导入数据：

# %%
import pandas as pd

# %%
path = "Online_Retail.csv"
original_data = pd.read_csv(path, encoding="cp1252", low_memory=False)

# %%
original_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## 评估数据

# %% [markdown]
# ### 评估整齐度

# %% [markdown]
# 抽样10行：

# %%
original_data.sample(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 460484    575918     23415                 HOME SWEET HOME HOOK         6
# 52453     540795     82582            AREA PATROLLED METAL SIGN        12
# 215565    555722    85099C       JUMBO  BAG BAROQUE BLACK WHITE         2
# 342156    566821     23234        BISCUIT TIN VINTAGE CHRISTMAS         6
# 149659    549296     21175          GIN + TONIC DIET METAL SIGN        12
# 427827    573402     21212      PACK OF 72 RETROSPOT CAKE CASES        24
# 392744    570715    85039B   S/4 IVORY MINI ROSE CANDLE IN BOWL        48
# 295758    562840     23297  SET 40 HEART SHAPE PETIT FOUR CASES         1
# 110604    545690     22822      CREAM WALL PLANTER HEART SHAPED         1
# 517540    580062     23406           HOME SWEET HOME KEY HOLDER         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 460484  11/11/11 16:58       1.65     17191.0  United Kingdom
# 52453    1/11/11 12:00       2.10     13078.0  United Kingdom
# 215565    6/6/11 16:06       4.13         NaN  United Kingdom
# 342156   9/15/11 11:33       2.89     14227.0  United Kingdom
# 149659     4/8/11 7:37       2.55     14619.0  United Kingdom
# 427827  10/30/11 15:44       0.55     12494.0          France
# 392744  10/12/11 10:23       1.45     18287.0  United Kingdom
# 295758    8/9/11 16:27       1.65     14527.0  United Kingdom
# 110604    3/6/11 12:46       5.95     13263.0  United Kingdom
# 517540   12/1/11 13:28       6.25     15862.0  United Kingdom

# %% [markdown]
# 不存在结构性问题

# %% [markdown]
# 看变量和非空缺值：

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# 结论：descpription和id存在缺失值，此外InvoiceData的数据类型应该是字符串，应当进行数据转换

# %% [markdown]
# ###评估缺失数据

# %% [markdown]
# 在了解完确实存在缺失值后，根据条件提取空缺值：

# %%
original_data[original_data["Description"].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity    InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/10 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/10 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/10 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/10 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/10 14:34        0.0
# ...          ...       ...         ...       ...            ...        ...
# 535322    581199     84581         NaN        -2  12/7/11 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/11 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/11 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/11 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/11 14:06        0.0
#
#         CustomerID         Country
# 622            NaN  United Kingdom
# 1970           NaN  United Kingdom
# 1971           NaN  United Kingdom
# 1972           NaN  United Kingdom
# 1987           NaN  United Kingdom
# ...            ...             ...
# 535322         NaN  United Kingdom
# 535326         NaN  United Kingdom
# 535332         NaN  United Kingdom
# 536981         NaN  United Kingdom
# 538554         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %% [markdown]
# 可以看到确实Description的数据，UnitPrice都为0.为了验证猜想，增加筛选条件，看是否存在Des变量缺失且UNIT不为0的数据

# %%
original_data[(original_data["Description"].isnull()) & (original_data["UnitPrice"] != 0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# 产品名和单价都是分析畅销产品的重要因素，缺失值就不在考虑范围之内了

# %% [markdown]
# ID也存在缺失值，进行提取

# %%
original_data[original_data["CustomerID"].isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/1/10 11:52       0.00         NaN  United Kingdom
# 1443    12/1/10 14:32       2.51         NaN  United Kingdom
# 1444    12/1/10 14:32       2.51         NaN  United Kingdom
# 1445    12/1/10 14:32       0.85         NaN  United Kingdom
# 1446    12/1/10 14:32       1.66         NaN  United Kingdom
# ...               ...        ...         ...             ...
# 541536  12/9/11 10:26       4.13         NaN  United Kingdom
# 541537  12/9/11 10:26       4.13         NaN  United Kingdom
# 541538  12/9/11 10:26       4.96         NaN  United Kingdom
# 541539  12/9/11 10:26      10.79         NaN  United Kingdom
# 541540  12/9/11 10:26    1714.17         NaN  United Kingdom
#
# [135080 rows x 8 columns]

# %% [markdown]
# ID标识客户编号，ID的缺失并不影响，可以保留为观察值

# %% [markdown]
# ### 评估重复数据

# %% [markdown]
# 针对此数据集，我们无需评估重复数据

# %% [markdown]
# ### 评估不一致数据

# %% [markdown]
# 不一致数据可以出现在Country中，我们要看是否存在不同的值代指同一国家的情况。

# %%
original_data["Country"].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: count, dtype: int64

# %% [markdown]
# 没啥问题u

# %%
original_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# 单价负数？

# %%
original_data[original_data["Quantity"] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 141      12/1/10 9:41      27.50     14527.0  United Kingdom
# 154      12/1/10 9:49       4.65     15311.0  United Kingdom
# 235     12/1/10 10:24       1.65     17548.0  United Kingdom
# 236     12/1/10 10:24       0.29     17548.0  United Kingdom
# 237     12/1/10 10:24       0.29     17548.0  United Kingdom
# ...               ...        ...         ...             ...
# 540449   12/9/11 9:57       0.83     14397.0  United Kingdom
# 541541  12/9/11 10:28     224.69     15498.0  United Kingdom
# 541715  12/9/11 11:57      10.95     15311.0  United Kingdom
# 541716  12/9/11 11:58       1.25     17315.0  United Kingdom
# 541717  12/9/11 11:58       1.25     17315.0  United Kingdom
#
# [10624 rows x 8 columns]

# %% [markdown]
# C开头的发票，是被取消的

# %%
original_data[(original_data["Quantity"] < 0) & (original_data["InvoiceNo"].str[0] != "C")]
# Out:
#        InvoiceNo StockCode Description  Quantity    InvoiceDate  UnitPrice  \
# 2406      536589     21777         NaN       -10  12/1/10 16:50        0.0
# 4347      536764    84952C         NaN       -38  12/2/10 14:42        0.0
# 7188      536996     22712         NaN       -20  12/3/10 15:30        0.0
# 7189      536997     22028         NaN       -20  12/3/10 15:30        0.0
# 7190      536998     85067         NaN        -6  12/3/10 15:30        0.0
# ...          ...       ...         ...       ...            ...        ...
# 535333    581210     23395       check       -26  12/7/11 18:36        0.0
# 535335    581212     22578        lost     -1050  12/7/11 18:38        0.0
# 535336    581213     22576       check       -30  12/7/11 18:38        0.0
# 536908    581226     23090     missing      -338   12/8/11 9:56        0.0
# 538919    581422     23169     smashed      -235  12/8/11 15:24        0.0
#
#         CustomerID         Country
# 2406           NaN  United Kingdom
# 4347           NaN  United Kingdom
# 7188           NaN  United Kingdom
# 7189           NaN  United Kingdom
# 7190           NaN  United Kingdom
# ...            ...             ...
# 535333         NaN  United Kingdom
# 535335         NaN  United Kingdom
# 535336         NaN  United Kingdom
# 536908         NaN  United Kingdom
# 538919         NaN  United Kingdom
#
# [1336 rows x 8 columns]

# %% [markdown]
# UNI都是0？

# %%
original_data[(original_data["Quantity"] < 0) & (original_data["InvoiceNo"].str[0] != "C") & (original_data["UnitPrice"] != 0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# 根据输出结果，Quantity 变量为负值时，要么C开头发票，要么uni为0，都是无效数据，可以进行删除

# %% [markdown]
# 接下来筛选UNI为负数的行

# %%
original_data[original_data["UnitPrice"] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity    InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/11 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/11 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# 也可以进行删除，没有意义

# %% [markdown]
# ### 清理数据

# %% [markdown]
# 根据前面的分析，我们需要进行的数据清理包括：
#   ①把InvoiceData变量数据类型转化为日期时间 ②把ID类型改为字符串 ③把DES缺失的观察值删除 ④把uni为负数的删除⑤把uni为负数的删除

# %% [markdown]
# 清理后的数据命名为cleaned_data

# %%
cleaned_data = original_data.copy()

# %% [markdown]
# 转换invoiceno类型

# %%
cleaned_data["InvoiceDate"] = pd.to_datetime(cleaned_data["InvoiceDate"])
cleaned_data["InvoiceDate"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %% [markdown]
# 把ID转化为字符串

# %%
cleaned_data["CustomerID"] = cleaned_data["CustomerID"].astype(str)
cleaned_data["CustomerID"]
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 541909, dtype: object

# %% [markdown]
# 把小数点.0删除

# %%
cleaned_data["CustomerID"].str.slice(0,4)
# Out:
# 0         1785
# 1         1785
# 2         1785
# 3         1785
# 4         1785
#           ...
# 541904    1268
# 541905    1268
# 541906    1268
# 541907    1268
# 541908    1268
# Name: CustomerID, Length: 541909, dtype: object

# %% [markdown]
# 删除des空缺值

# %%
cleaned_data = cleaned_data.dropna(subset = ["Description"])
cleaned_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 0      2010-12-01 08:26:00       2.55    17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39    17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75    17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39    17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39    17850.0  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2011-12-09 12:50:00       0.85    12680.0          France
# 541905 2011-12-09 12:50:00       2.10    12680.0          France
# 541906 2011-12-09 12:50:00       4.15    12680.0          France
# 541907 2011-12-09 12:50:00       4.15    12680.0          France
# 541908 2011-12-09 12:50:00       4.95    12680.0          France
#
# [540455 rows x 8 columns]

# %%
cleaned_data["Description"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 把quan负数值删除

# %%
cleaned_data = cleaned_data[cleaned_data["Quantity"] >= 0]

# %%
len(cleaned_data[cleaned_data["Quantity"] < 0])
# Out:
# 0

# %%
cleaned_data = cleaned_data[cleaned_data["UnitPrice"] >= 0]

# %%
len(cleaned_data[cleaned_data["UnitPrice"] < 0])
# Out:
# 0

# %% [markdown]
# ## 保存清理后的数据

# %% [markdown]
# 完成数据清理后，命名为新的文件

# %%
cleaned_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom

# %%
cleaned_data.to_csv("Online_Retail_cleaned.csv", index = False)

# %%
pd.read_csv("Online_Retail_cleaned.csv").head()
# Out:
# C:\Users\86136\AppData\Local\Tem\ipykernel_35648\354951637.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("Online_Retail_cleaned.csv").head()
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
